# %%
from tabula import read_pdf
import tabula
import pandas as pd
import numpy as np
input_file='data/DCvsSRH-1902ki6burpf7--7-3738051775.pdf'
output_file='output3.csv'
pages=2

df = read_pdf(input_file, pages=pages,lattice=True)

# %%
tabula.convert_into(input_file, output_file, output_format="csv", pages="1-"+str(pages))

# %%
teams=pd.read_csv(output_file,skiprows=1)
teams.count()
# Out:
# User (Team)                132
# Player 1 (Captain)         132
# Player 2 (Vice Captain)    132
# Player 3                   132
# Player 4                   132
# Player 5                   132
# Player 6                   132
# Player 7                   132
# Player 8                   132
# Player 9                   132
# Player 10                  132
# Player 11                  132
# dtype: int64

# %%
teams
# Out:
#           User (Team) Player 1 (Captain) Player 2 (Vice Captain)  \
# 0     T  AADHAVAN (1)     Shikhar Dhawan           Kagiso Rabada
# 1     T  AADHAVAN (2)     Shikhar Dhawan         Kane Williamson
# 2     T  AADHAVAN (3)     Shikhar Dhawan           Manish Pandey
# 3     T  AADHAVAN (4)    Kane Williamson          Ajinkya Rahane
# 4     T  AADHAVAN (5)       David Warner            Shreyas Iyer
# ..                ...                ...                     ...
# 127    T D Tagung (1)      Kagiso Rabada           Manish Pandey
# 128        t data (2)    Wriddhiman Saha             T Natarajan
# 129  t Dawa aryan (4)     Ajinkya Rahane         Wriddhiman Saha
# 130  t Dawa aryan (5)      Kagiso Rabada          Marcus Stoinis
# 131      T dhakar (7)      Manish Pandey         Kane Williamson
#
#            Player 3         Player 4        Player 5         Player 6  \
# 0     Anrich Nortje       Axar Patel    Jason Holder  Kane Williamson
# ...
